# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\0sagiede\Documents\finance_dataset_dirty.csv")

# %%
data
# Out:
#        TransactionID TransactionDate  ClientID  TransactionAmount  \
# 0           954727.0      2022-08-13       NaN       -3740.356038
# 1           742306.0      2023-07-12       NaN        6791.629187
# 2           383126.0      2023-06-15    5409.0        -684.205070
# 3           752619.0      2022-08-20    6297.0       -4400.673938
# 4           228778.0      2023-06-04    9422.0       14203.820776
# ...              ...             ...       ...                ...
# 20995       745115.0      2022-10-12    7371.0        -554.958841
# 20996       254542.0      2022-07-14    7377.0        9144.179610
# 20997       787100.0      2022-05-04    6599.0       11684.127229
# 20998       896177.0      2021-06-27    2737.0        2799.230671
# 20999       711369.0      2021-01-22    4736.0         131.810964
#
#       TransactionType    AccountType Location  ClientAge  ClientIncome  \
# 0              Refund            NaN    Enugu       56.0  2.781730e+07
# ...

# %%
data.head(25)
# Out:
#     TransactionID TransactionDate  ClientID  TransactionAmount  \
# 0        954727.0      2022-08-13       NaN       -3740.356038
# 1        742306.0      2023-07-12       NaN        6791.629187
# 2        383126.0      2023-06-15    5409.0        -684.205070
# 3        752619.0      2022-08-20    6297.0       -4400.673938
# 4        228778.0      2023-06-04    9422.0       14203.820776
# 5        943353.0      2022-11-30    1362.0        9210.637658
# 6        719696.0             NaN       NaN        -748.369628
# 7        872793.0      2021-04-22    9374.0        4087.558508
# 8        603623.0      2021-08-07    6010.0        -818.409795
# 9        823439.0      2023-09-01    7274.0       -3782.855478
# 10       157676.0      2023-10-13    7407.0                NaN
# 11       687069.0      2022-12-31    8899.0        1129.428337
# 12       790807.0      2021-08-14    1869.0       -1254.094077
# 13       231436.0      2021-04-16    7996.0       13999.890873
# ...

# %%
data.tail(5)
# Out:
#        TransactionID TransactionDate  ClientID  TransactionAmount  \
# 20995       745115.0      2022-10-12    7371.0        -554.958841
# 20996       254542.0      2022-07-14    7377.0        9144.179610
# 20997       787100.0      2022-05-04    6599.0       11684.127229
# 20998       896177.0      2021-06-27    2737.0        2799.230671
# 20999       711369.0      2021-01-22    4736.0         131.810964
#
#       TransactionType    AccountType Location  ClientAge   ClientIncome  \
# 20995             NaN            NaN    Lagos       22.0   95406.605904
# 20996          Credit        Savings    Abuja       60.0  432535.810148
# 20997             NaN  Fixed Deposit    Abuja        NaN  219758.709528
# 20998          Refund        Savings    Enugu       69.0  171357.170499
# 20999          Refund        Savings     Kano       45.0  367030.462705
#
#       ApprovalStatus
# 20995       Approved
# 20996       Rejected
# 20997       Rejected
# 20998       Approved
# 20999        Pending

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      18890 non-null  float64
#  1   TransactionDate    18909 non-null  object
#  2   ClientID           18895 non-null  float64
#  3   TransactionAmount  18902 non-null  float64
#  4   TransactionType    18896 non-null  object
#  5   AccountType        18907 non-null  object
#  6   Location           18891 non-null  object
#  7   ClientAge          18906 non-null  float64
#  8   ClientIncome       18901 non-null  float64
#  9   ApprovalStatus     18896 non-null  object
# dtypes: float64(5), object(5)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#        TransactionID      ClientID  TransactionAmount     ClientAge  \
# count   18890.000000  18895.000000       1.890200e+04  18906.000000
# mean   554274.338909   5494.901402       1.497568e+04     48.404528
# std    260345.925334   2606.470873       1.081739e+05     17.848731
# min    100005.000000   1000.000000      -4.995817e+05     18.000000
# 25%    331463.000000   3212.000000       9.272916e+01     33.000000
# 50%    556209.000000   5489.000000       5.093524e+03     48.000000
# 75%    780217.250000   7763.000000       1.036786e+04     64.000000
# max    999993.000000   9998.000000       1.494519e+06     79.000000
#
#        ClientIncome
# count  1.890100e+04
# mean   7.715512e+05
# std    4.102826e+06
# min    1.501774e+04
# 25%    1.389500e+05
# 50%    2.617160e+05
# 75%    3.863267e+05
# max    4.998831e+07

# %%
data.shape
# Out:
# (21000, 10)

# %%
data.dtypes
# Out:
# TransactionID        float64
# TransactionDate       object
# ClientID             float64
# TransactionAmount    float64
# TransactionType       object
# AccountType           object
# Location              object
# ClientAge            float64
# ClientIncome         float64
# ApprovalStatus        object
# dtype: object

# %%
data.value_counts()
# Out:
# TransactionID  TransactionDate  ClientID  TransactionAmount  TransactionType  AccountType    Location       ClientAge  ClientIncome   ApprovalStatus
# 772633.0       2023-10-30       8038.0     1860.700937       Debit            Current        Kano           56.0       282642.926482  Rejected          2
# 936659.0       2022-05-12       7681.0     14855.146787      Credit           Savings        Port Harcourt  62.0       439576.587073  Rejected          2
# 504303.0       2021-01-18       1661.0     9074.524933       Debit            Savings        Kano           31.0       486959.741194  Pending           2
# 281871.0       2021-05-15       6990.0     7481.673000       Debit            Current        Kano           69.0       207936.337628  Approved          2
# 938357.0       2023-02-03       8548.0     6877.791784       Debit            Fixed Deposit  Lagos          56.0       348898.318664  Pending           2
# ...

# %%
data.sample(200)
# Out:
#        TransactionID TransactionDate  ClientID  TransactionAmount  \
# 19506       477591.0      2022-02-04    7611.0        7298.343926
# 3456        311830.0      2023-05-27    9417.0        4809.083743
# 3297        241668.0      2023-10-21    3146.0       11792.772880
# 16972       688518.0      2023-08-31       NaN        4011.051657
# 19275       921681.0      2023-08-12    5020.0                NaN
# ...              ...             ...       ...                ...
# 3605        457470.0      2021-04-01       NaN                NaN
# 11481       556339.0      2022-11-14    7459.0       11811.836321
# 136         181748.0      2021-08-16    5461.0       -2176.394710
# 19632       818216.0             NaN    4112.0       -1375.544285
# 5079        377533.0      2021-12-22    9682.0       11348.231828
#
#       TransactionType    AccountType       Location  ClientAge   ClientIncome  \
# 19506           Debit        Current          Abuja       21.0  235737.304308
# ...

# %%
data.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'ClientID', 'TransactionAmount',
#        'TransactionType', 'AccountType', 'Location', 'ClientAge',
#        'ClientIncome', 'ApprovalStatus'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=21000, step=1)

# %%
data.isnull().sum()
# Out:
# TransactionID        2110
# TransactionDate      2091
# ClientID             2105
# TransactionAmount    2098
# TransactionType      2104
# AccountType          2093
# Location             2109
# ClientAge            2094
# ClientIncome         2099
# ApprovalStatus       2104
# dtype: int64

# %%
data.isnull().sum()*100/len(data)
# Out:
# TransactionID        10.047619
# TransactionDate       9.957143
# ClientID             10.023810
# TransactionAmount     9.990476
# TransactionType      10.019048
# AccountType           9.966667
# Location             10.042857
# ClientAge             9.971429
# ClientIncome          9.995238
# ApprovalStatus       10.019048
# dtype: float64

# %%
data.nunique()
# Out:
# TransactionID        17832
# TransactionDate       1095
# ClientID              7791
# TransactionAmount    18039
# TransactionType          3
# AccountType              3
# Location                 5
# ClientAge               62
# ClientIncome         18040
# ApprovalStatus           3
# dtype: int64
